# %% [markdown]
# ### Datasets
#
# - **[USGS:64d272bfd34ef477cf3cc30f](https://data.usgs.gov/datacatalog/data/USGS:64d272bfd34ef477cf3cc30f)** Digitized sonic velocity and density log data of Sacramento Valley, California
# <!-- https://data.usgs.gov/datacatalog/data/USGS:64d15b1dd34ef477cf3c0228 -->
# - **[USGS:64d15b1dd34ef477cf3c0228](https://data.usgs.gov/datacatalog/data/USGS:64d15b1dd34ef477cf3c0228)** Drilling, construction, geophysical data, and lithologic log for borehole USGS 145
# <!-- https://data.usgs.gov/datacatalog/data/USGS:63e25e99d34e9fa19a9b84fc -->
# - **[USGS:63e25e99d34e9fa19a9b84fc](https://data.usgs.gov/datacatalog/data/USGS:63e25e99d34e9fa19a9b84fc)** United States Gulf Coast Basin Curated Wells and Logs Database (ver. 2.0, November 2023)
# <!-- https://data.usgs.gov/datacatalog/data/USGS:5bfd6397e4b0815414ca573e -->
# - **[USGS:5bfd6397e4b0815414ca573e](https://data.usgs.gov/datacatalog/data/USGS:5bfd6397e4b0815414ca573e)** Digitized Historical Borehole Geophysical Logs in and near the Mississippi Alluvial Plain Aquifer System
# <!-- https://data.usgs.gov/datacatalog/data/USGS:64da9e5fd34ef477cf3ee769 -->
# - **[USGS:64da9e5fd34ef477cf3ee769](https://data.usgs.gov/datacatalog/data/USGS:64da9e5fd34ef477cf3ee769)** A dataset of scanned historical well and geophysical logs from 141 counties in Texas, 1918–2020 (ver. 2.0, September 2024)

# %% [markdown]
# ### APIs

# %%
import requests
import os

# Base URL for ScienceBase API
BASE_URL = "https://www.sciencebase.gov/catalog/item/"

def download_sdc_data(item_id, save_dir="data"):
    """
    Downloads data files associated with a ScienceBase Catalog item.

    Args:
        item_id (str): ScienceBase Catalog item ID.
        save_dir (str): Directory to save downloaded files.
    """
    # Ensure the save directory exists
    save_dir = save_dir + f"/{item_id}"
    os.makedirs(save_dir, exist_ok=True)
    
    # Construct the metadata URL
    item_url = f"{BASE_URL}{item_id}?format=json"
    response = requests.get(item_url)
    
    # Check for successful response
    if response.status_code != 200:
        print(f"Error fetching data: {response.status_code}")
        return

    # Parse the JSON metadata
    item_data = response.json()
    print(f"Title: {item_data.get('title', 'No Title')}")
    
    # Get the files listed in the item
    files = item_data.get("files", [])
    if not files:
        print("No files available for download.")
        return
    
    # Download each file
    for file_info in files:
        file_url = file_info.get("url")
        file_name = file_info.get("name", "unknown")
        
        if file_url:
            print(f"Downloading {file_name} from {file_url}...")
            file_response = requests.get(file_url, stream=True)
            
            if file_response.status_code == 200:
                file_path = os.path.join(save_dir, file_name)
                with open(file_path, "wb") as file:
                    for chunk in file_response.iter_content(chunk_size=8192):
                        file.write(chunk)
                print(f"Saved {item_id} to {file_path}")
            else:
                print(f"Failed to download {file_name}: {file_response.status_code}")

# %%
data_id_lists = ['64d272bfd34ef477cf3cc30f', '64d15b1dd34ef477cf3c0228', '63e25e99d34e9fa19a9b84fc', '5bfd6397e4b0815414ca573e', '64da9e5fd34ef477cf3ee769']

# Saved 63e25e99d34e9fa19a9b84fc to data/63e25e99d34e9fa19a9b84fc/browse_graphic.JPG
# Downloading JPG - 00000-08400 - 270 files 1-1 GB.zip from https://www.sciencebase.gov/catalog/file/get/63e25e99d34e9fa19a9b84fc?f=__disk__46%2F85%2Faa%2F4685aabce02292697692653eee87abe530017ca3...
# Saved 63e25e99d34e9fa19a9b84fc to data/63e25e99d34e9fa19a9b84fc/JPG - 00000-08400 - 270 files 1-1 GB.zip
# Downloading JPG - 08400-16000 - 269 files 1-1 GB.zip from https://www.sciencebase.gov/catalog/file/get/63e25e99d34e9fa19a9b84fc?f=__disk__88%2F97%2Fe7%2F8897e718f6ace1dbc50b693f1828c718c554e9a7...
# Saved 63e25e99d34e9fa19a9b84fc to data/63e25e99d34e9fa19a9b84fc/JPG - 08400-16000 - 269 files 1-1 GB.zip
# Downloading 42311015320000_NUECES_A-1.las from https://www.sciencebase.gov/catalog/file/get/63e25e99d34e9fa19a9b84fc?f=__disk__e1%2F31%2Fc9%2Fe131c9cbdd0766a339643597cffa1ceaff14a087...
# Saved 63e25e99d34e9fa19a9b84fc to data/63e25e99d34e9fa19a9b84fc/42311015320000_NUECES_A-1.las
# Downloading 42479343960000_NICHOLSON_RANCH_1.las from https://www.sciencebase.gov/catalog/file/get/63e25e99d34e9fa19a9b84fc?f=__disk__0d%2F62%2F76%2F0d62761a21874e2cd1ab52f25ab675de853168c3...
# Saved 63e25e99d34e9fa19a9b84fc to data/63e25e99d34e9fa19a9b84fc/42479343960000_NICHOLSON_RANCH_1.las
# Downloading CWLDB_DR_WellTable_ver3.csv from https://www.sciencebase.gov/catalog/file/get/63e25e99d34e9fa19a9b84fc?f=__disk__7f%2F38%2F19%2F7f3819ea4b07777117b383c3c0703353a047dd27...
# Saved 63e25e99d34e9fa19a9b84fc to data/63e25e99d34e9fa19a9b84fc/CWLDB_DR_WellTable_ver3.csv
# Downloading CWLDB_ver3_Metadata.xml from https://www.sciencebase.gov/catalog/file/get/63e25e99d34e9fa19a9b84fc?f=__disk__be%2F50%2F4b%2Fbe504bb0159b2ba7a744471bb4fd65796fb1842e...
# Saved 63e25e99d34e9fa19a9b84fc to data/63e25e99d34e9fa19a9b84fc/CWLDB_ver3_Metadata.xml
# Downloading Product_10.5066P95BNWT3_DATA_Revision-History.txt from https://www.sciencebase.gov/catalog/file/get/63e25e99d34e9fa19a9b84fc?f=__disk__e3%2F5c%2Fa9%2Fe35ca96c11472c6811ca2598955a6fd2e2966410...
# Saved 63e25e99d34e9fa19a9b84fc to data/63e25e99d34e9fa19a9b84fc/Product_10.5066P95BNWT3_DATA_Revision-History.txt
# Title: Digitized Historical Borehole Geophysical Logs in and near the Mississippi Alluvial Plain Aquifer System (ver. 2.0, January 2021)
# Downloading WELLSet1_Collar.txt from https://www.sciencebase.gov/catalog/file/get/5bfd6397e4b0815414ca573e?f=__disk__cd%2F7b%2Fa8%2Fcd7ba809b49dd0ed92471691dace0b775c879d10...
# Saved 5bfd6397e4b0815414ca573e to data/5bfd6397e4b0815414ca573e/WELLSet1_Collar.txt
# Downloading WELLSet1_Data.txt from https://www.sciencebase.gov/catalog/file/get/5bfd6397e4b0815414ca573e?f=__disk__ad%2F13%2F40%2Fad1340956ee479d80116bf3bbb329da3a4730011...
# Saved 5bfd6397e4b0815414ca573e to data/5bfd6397e4b0815414ca573e/WELLSet1_Data.txt
# Downloading MAPWellLogRevision History_jdg.txt from https://www.sciencebase.gov/catalog/file/get/5bfd6397e4b0815414ca573e?f=__disk__26%2F4c%2F3a%2F264c3a60dce7b0976763f1c7479aae71eae3faf4...
# Saved 5bfd6397e4b0815414ca573e to data/5bfd6397e4b0815414ca573e/MAPWellLogRevision History_jdg.txt
# Downloading WellSet1_Metadata.xml from https://www.sciencebase.gov/catalog/file/get/5bfd6397e4b0815414ca573e?f=__disk__be%2F9a%2Fde%2Fbe9adedc9aa91349d8c417ded822cbc32dda7d34...
# Saved 5bfd6397e4b0815414ca573e to data/5bfd6397e4b0815414ca573e/WellSet1_Metadata.xml
# Title: A dataset of scanned historical well and geophysical logs from 141 counties in Texas, 1918–2020 (ver. 2.0, September 2024)
# Downloading PDF_LogScan_Dataset_Counties_A-B.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jlxf1l00530vpghido7oeu...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_A-B.zip
# Downloading PDF_LogScan_Dataset_Counties_Bastrop_2.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jmv3pj005a0vpg19b111xx...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Bastrop_2.zip
# Downloading PDF_LogScan_Dataset_Counties_Bastrop_1.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jmwixk005b0vpg4semhrtw...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Bastrop_1.zip
# Downloading PDF_LogScan_Dataset_Counties_Bastrop_4.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jnpmy200u50uoc0awhbif0...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Bastrop_4.zip
# Downloading PDF_LogScan_Dataset_Counties_Bastrop_5.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jnsbe5005h0vpg5kg8g4gw...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Bastrop_5.zip
# Downloading PDF_LogScan_Dataset_Counties_Bastrop_3.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jmxa9z00tq0uoch4j94vb5...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Bastrop_3.zip
# Downloading PDF_LogScan_Dataset_Counties_Bastrop_8.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jol6ss00uf0uocfaod5z0x...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Bastrop_8.zip
# Downloading PDF_LogScan_Dataset_Counties_Bastrop_7.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1joom6d005l0vpgam2odtno...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Bastrop_7.zip
# Downloading PDF_LogScan_Dataset_Counties_Bastrop_6.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1joozbc005m0vpgg1mk09ds...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Bastrop_6.zip
# Downloading PDF_LogScan_Dataset_Counties_E-F.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jpnmx4005o0vpgbidn8rej...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_E-F.zip
# Downloading PDF_LogScan_Dataset_Counties_D-E.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jpnphf00ug0uocgcv46a7c...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_D-E.zip
# Downloading PDF_LogScan_Dataset_Counties_B-C.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jpnuu200uh0uocc3231h3i...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_B-C.zip
# Downloading PDF_LogScan_Dataset_Counties_Fayette_1.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jqv5n700uj0uocfms21leb...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Fayette_1.zip
# Downloading PDF_LogScan_Dataset_Counties_Fayette_2.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jqv83r00uk0uoc5gxwavgv...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Fayette_2.zip
# Downloading PDF_LogScan_Dataset_Counties_Fayette_3.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jqv9u100ul0uoca3q23ws9...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Fayette_3.zip
# Downloading PDF_LogScan_Dataset_Counties_Fayette_4.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jqvbfu00um0uocg4wmgijx...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_Fayette_4.zip
# Downloading PDF_LogScan_Dataset_Counties_M-Z.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jrr6gr00650vpg5ed8501p...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_M-Z.zip
# Downloading PDF_LogScan_Dataset_Counties_K-L.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jrw34500660vpg6tbb8h98...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_K-L.zip
# Downloading PDF_LogScan_Dataset_Counties_L-M.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jrv7d800ur0uoc0tkd7594...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_L-M.zip
# Downloading PDF_LogScan_Dataset_Counties_G-I.zip from https://sciencebase.usgs.gov/manager/item/64da9e5fd34ef477cf3ee769/file/cm1jt5ar500v60uocehwp1y78...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/PDF_LogScan_Dataset_Counties_G-I.zip
# Downloading Log_Scan_Database.accdb from https://www.sciencebase.gov/catalog/file/get/64da9e5fd34ef477cf3ee769?f=__disk__9e%2F96%2F97%2F9e96978b40e6d514c443c55dd3b4066cd7466b57...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/Log_Scan_Database.accdb
# Downloading Log_Scan_Database.csv from https://www.sciencebase.gov/catalog/file/get/64da9e5fd34ef477cf3ee769?f=__disk__df%2F05%2F79%2Fdf05792176342ae07dbaede11291d68659c5b8a4...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/Log_Scan_Database.csv
# Downloading Log_Scan_Database_Metadata.xml from https://www.sciencebase.gov/catalog/file/get/64da9e5fd34ef477cf3ee769?f=__disk__d1%2Fb4%2Fee%2Fd1b4ee99d1cb817926fb387011b870935195e0a8...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/Log_Scan_Database_Metadata.xml
# Downloading Version_History.txt from https://www.sciencebase.gov/catalog/file/get/64da9e5fd34ef477cf3ee769?f=__disk__6e%2Fb9%2F3c%2F6eb93c613aa2a05dd7cbbcd4b933bb6974e619bc...
# Saved 64da9e5fd34ef477cf3ee769 to data/64da9e5fd34ef477cf3ee769/Version_History.txt
